# %%
import mpbn
from colomoto_jupyter import tabulate

# %%
#Configuration 1
mbn1 = mpbn.MPBooleanNetwork({
    "clk1": "0",
    "ETC": "clk1",
    "pink1": "!ETC",
    "skn1": "ros or !ETC",
    "taf4": "!clk1",
    "met": "!hif1",
    "hlh11": "!atfs1 and !mtor",
    "unc51": "ampk and !mtor",
    "hlh30": "!mtor",
    "creb": "taf4 and !crtc1",
    "UP": "!clk1 and (ETC2 or !hsp60)",
    "ATG": "unc51 and hlh30",
    "lipl4": "hlh30",
    "MTG": "pink1 and skn1 and unc51",
    "fzo1": "creb",
    "clpp1": "UP",
    "LDs": "ATG",
    "ETC2": "fzo1 and MTG",
    "atfs1": "clpp1",
    "ros": "ETC2 or (!ampk and !clk1)",
    "hsp60": "atfs1",
    "hif1": "ros",
    "atgl1": "!hlh11",
    "lip": "lipl4 and LDs and atgl1",
    "betaox": "lip",
    "ATP": "(ETC2 and betaox) or ETC",
    "crtc1": "!ampk",
    "mtor": "!ampk and !unc51",
    "ampk": "!ATP or (ros and !hif1)"
})

# %%
#Configuration 2
mbn2 = mpbn.MPBooleanNetwork({
    "clk1": "0",
    "ETC": "clk1",
    "pink1": "!ETC",
    "skn1": "ros or !ETC",
    "taf4": "!clk1",
    "met": "!hif1",
    "hlh11": "!atfs1 and !mtor",
    "unc51": "ampk and !mtor",
    "hlh30": "!mtor",
    "creb": "taf4 and !crtc1",
    "UP": "!clk1 and (ETC2 or !hsp60)",
    "ATG": "unc51 and hlh30",
    "lipl4": "hlh30",
    "MTG": "pink1 and skn1 and unc51",
    "fzo1": "creb",
    "clpp1": "UP",
    "LDs": "ATG",
    "ETC2": "fzo1 and MTG",
    "atfs1": "clpp1",
    "ros": "!ETC and (!ampk or hif1)",
    "hsp60": "atfs1",
    "hif1": "ros and !ampk",
    "atgl1": "!hlh11",
    "lip": "lipl4 and LDs and atgl1",
    "betaox": "lip",
    "ATP": "(ETC2 and betaox) or ETC",
    "crtc1": "!ampk",
    "mtor": "!ampk and !unc51",
    "ampk": "ros and !hif1"
})

# %%
#Atracctors for configuration 1
# %time a = list(mbn1.attractors())
tabulate(a)

# %%
#Atracctors for configuration 2
# %time b = list(mbn2.attractors())
tabulate(b)
